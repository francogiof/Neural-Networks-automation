# %% [markdown]
# # AnyoneAI - Sprint Project 02
# > Home Credit Default Risk
#
# You've been learning a lot about Machine Learning Algorithms, now we you're gonna be asked to put it all togheter.
#
# You will create a complete pipeline to preprocess the data, train your model and then predict values for the [Home Credit Default Risk](https://www.kaggle.com/competitions/home-credit-default-risk/) Kaggle competition.

# %% [markdown]
# ## 1. Introduction
#
# This is a binary Classification task: we want to predict whether the person applying for a home credit will be able to repay their debt or not. Our model will have to predict a 1 indicating the client will have payment difficulties: he/she will have late payment of more than X days on at least one of the first Y installments of the loan in our sample, 0 in all other cases.
#
# The dataset is composed of multiple files with different information about loans taken. In this project, we will work exclusively with the primary files: `application_train_aai.csv` and `application_test_aai.csv`.
#
# We will use [Area Under the ROC Curve](https://developers.google.com/machine-learning/crash-course/classification/roc-and-auc?hl=es_419) as the evaluation metric, so our models will have to return the probabilities that a loan is not paid for each row.

# %%
# Import libraries
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import RandomizedSearchCV
from sklearn.utils.validation import check_is_fitted
from imblearn.combine import SMOTETomek
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from src import config, data_utils, preprocessing

# %%
app_train, app_test, columns_description = data_utils.get_datasets()


if app_train.shape == (246008, 122):
    print("Success: app_train shape is correct!")
else:
    raise ValueError("Train dataset shape is incorrect, please review your code")

if isinstance(app_train, pd.DataFrame):
    print("Success: app_train type is correct!")
else:
    raise ValueError("Train dataset type is incorrect, please review your code")

if app_test.shape == (61503, 122):
    print("Success: app_test shape is correct!")
else:
    raise ValueError("Test dataset shape is incorrect, please review your code")

if isinstance(app_test, pd.DataFrame):
    print("Success: app_test type is correct!")
else:
    raise ValueError("Test dataset type is incorrect, please review your code")
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1e8jbK4zNv95Yd2acycf27MbrDcCwAgFS&confirm=t
# To: /Users/usuario/Sites/anyone/assignment-sprint-02-template/dataset/HomeCredit_columns_description.csv
# 100%|██████████| 24.6k/24.6k [00:00<00:00, 894kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1sXWs2hyG34xFzRepf9fOKkCXq4kGjMT5&confirm=t
# To: /Users/usuario/Sites/anyone/assignment-sprint-02-template/dataset/application_test_aai.csv
# 100%|██████████| 33.1M/33.1M [00:05<00:00, 6.07MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vT0u2xndjNFIE-gCoW7s0tJuV4aPyz0B&confirm=t
# To: /Users/usuario/Sites/anyone/assignment-sprint-02-template/dataset/application_train_aai.csv
# 100%|██████████| 132M/132M [00:16<00:00, 8.02MB/s]
# Success: app_train shape is correct!
# Success: app_train type is correct!
# Success: app_test shape is correct!
# Success: app_test type is correct!

# %%
# Now we execute the function above to get the result
X_train, y_train, X_test, y_test = data_utils.get_feature_target(app_train, app_test)


if X_train.shape == (246008, 121):
    print("Success: X_train shape is correct!")
else:
    raise ValueError("X_train dataset shape is incorrect, please review your code")

if isinstance(X_train, pd.DataFrame):
    print("Success: X_train type is correct!")
else:
    raise ValueError("Train dataset type is incorrect, please review your code")

if y_train.shape == (246008,) or y_train.shape == (246008, 1):
    print("Success: y_train shape is correct!")
else:
    raise ValueError("Train labels shape is incorrect, please review your code")

if X_test.shape == (61503, 121):
    print("Success: X_test shape is correct!")
else:
    raise ValueError("Test dataset shape is incorrect, please review your code")

if isinstance(X_test, pd.DataFrame):
    print("Success: X_test type is correct!")
else:
    raise ValueError("Test dataset type is incorrect, please review your code")

if y_test.shape == (61503,) or y_test.shape == (61503, 1):
    print("Success: y_test shape is correct!")
else:
    raise ValueError("Test labels shape is incorrect, please review your code")
# Out:
# Success: X_train shape is correct!
# Success: X_train type is correct!
# Success: y_train shape is correct!
# Success: X_test shape is correct!
# Success: X_test type is correct!
# Success: y_test shape is correct!

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
# Now we execute the function above to get the result
X_train, X_val, y_train, y_val = data_utils.get_train_val_sets(X_train, y_train)


if X_train.shape == (196806, 121):
    print("Success: X_train shape is correct!")
else:
    raise ValueError("X_train dataset shape is incorrect, please review your code")

if isinstance(X_train, pd.DataFrame):
    print("Success: X_train type is correct!")
else:
    raise ValueError("Train dataset type is incorrect, please review your code")

if y_train.shape == (196806,) or y_train.shape == (196806, 1):
    print("Success: y_train shape is correct!")
else:
    raise ValueError("Train labels shape is incorrect, please review your code")

if X_val.shape == (49202, 121):
    print("Success: X_test shape is correct!")
else:
    raise ValueError("Test dataset shape is incorrect, please review your code")

if isinstance(X_val, pd.DataFrame):
    print("Success: X_test type is correct!")
else:
    raise ValueError("Test dataset type is incorrect, please review your code")

if y_val.shape == (49202,) or y_val.shape == (49202, 1):
    print("Success: y_test shape is correct!")
else:
    raise ValueError("Test labels shape is incorrect, please review your code")
# Out:
# Success: X_train shape is correct!
# Success: X_train type is correct!
# Success: y_train shape is correct!
# Success: X_test shape is correct!
# Success: X_test type is correct!
# Success: y_test shape is correct!

# %% [markdown]
# **Don't change anything in this cell, just make it run correctly**

# %%
train_data, val_data, test_data = preprocessing.preprocess_data(X_train, X_val, X_test)


if train_data.shape == (196806, 246):
    print("Success: train_data shape is correct!")
else:
    raise ValueError("train_data dataset shape is incorrect, please review your code")

if isinstance(train_data, np.ndarray):
    print("Success: train_data type is correct!")
else:
    raise ValueError("Train dataset type is incorrect, please review your code")

if val_data.shape == (49202, 246):
    print("Success: val_data shape is correct!")
else:
    raise ValueError("val_data dataset shape is incorrect, please review your code")

if isinstance(val_data, np.ndarray):
    print("Success: val_data type is correct!")
else:
    raise ValueError("Validation dataset type is incorrect, please review your code")

if test_data.shape == (61503, 246):
    print("Success: test_data shape is correct!")
else:
    raise ValueError("test_data dataset shape is incorrect, please review your code")

if isinstance(test_data, np.ndarray):
    print("Success: test_data type is correct!")
else:
    raise ValueError("Test dataset type is incorrect, please review your code")
# Out:
# Input train data shape:  (196806, 121)
# Input val data shape:  (49202, 121)
# Input test data shape:  (61503, 121)
# /Users/usuario/Sites/anyone/assignment-sprint-02-template/src/preprocessing.py:38: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   working_train_df["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace=True)
# /Users/usuario/Sites/anyone/assignment-sprint-02-template/src/preprocessing.py:39: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   working_val_df["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace=True)
# /Users/usuario/Sites/anyone/assignment-sprint-02-template/src/preprocessing.py:40: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   working_test_df["DAYS_EMPLOYED"].replace({365243: np.nan}, inplace=True)
# Creating essential new features...
# Encoding categorical features...
# Imputing missing values...
# Current feature count: 248
# Scaling features...
# Final feature count: 248
# Final processed shapes:
# Processed train data shape:  (196806, 246)
# Processed val data shape:  (49202, 246)
# Processed test data shape:  (61503, 246)
#
# Success: train_data shape is correct!
# Success: train_data type is correct!
# Success: val_data shape is correct!
# Success: val_data type is correct!
# Success: test_data shape is correct!
# Success: test_data type is correct!

# %% [markdown]
# ## 3. Training Models

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.metrics import roc_auc_score, make_scorer

X = train_data  # Features  
y = y_train     # target

kf = KFold(n_splits=5, shuffle=True, random_state=42)

folds = list(kf.split(X))

# %%
X = pd.DataFrame(X)  
y = pd.Series(y)    
# Seleccionar el cuarto fold para ahorrar tiempo en ejecución
train_idx, val_idx = folds[3]
X_train_fold, y_train_fold = X.iloc[train_idx], y.iloc[train_idx]
X_val_fold, y_val_fold = X.iloc[val_idx], y.iloc[val_idx]

# %%
from src.grid_search import grid_search

param_grid = {
    'n_estimators': [150, 200],           
    'max_depth': [8, 10],                     
    'min_samples_split': [2, 3, 5],              
    'min_samples_leaf': [1, 2],                  
    'max_features': [0.5, 0.6],         
    'class_weight': ['balanced', {0: 1, 1: 8}, {0: 1, 1: 12}]  
}
    # total combinations = 2 * 2 * 3 * 2 * 2 * 3 = 144

# %%
grid_search(
  params = param_grid,
  instance_id=0, # CHANGE THIS BETWEEN 0 AND 7
  X_train_fold=X_train_fold, 
  y_train_fold=y_train_fold, 
  X_val_fold=X_val_fold, 
  y_val_fold=y_val_fold
  )
# Out:
# Searching for instance 1
# Evaluando combinaciones 0 a 60 (total: 61)
# ✓ Data loaded - Train: (157445, 246), Val: (39361, 246)
#
# Starting process to instance: 01 with 61 combinations...
#
#  Evaluate combination: 01/61 (global 0):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 230.39 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0457
#  F1 Score: 0.2610
#  Precision Score: 0.1655
#  Recall Score: 0.6166
#  New model found! (F1: 0.2610)
#
#  Evaluate combination: 02/61 (global 1):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 223.28 seconds
#  ROC AUC Score (train): 0.7830
#  ROC AUC Score (Test): 0.7388
#  Difference AUC: 0.0442
#  F1 Score: 0.2811
#  Precision Score: 0.2001
#  Recall Score: 0.4726
#  New model found! (F1: 0.2811)
#
#  Evaluate combination: 03/61 (global 2):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 224.99 seconds
#  ROC AUC Score (train): 0.7838
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0456
#  F1 Score: 0.2577
#  Precision Score: 0.1617
#  Recall Score: 0.6346
#
#  Evaluate combination: 04/61 (global 3):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 258.56 seconds
#  ROC AUC Score (train): 0.7851
#  ROC AUC Score (Test): 0.7386
#  Difference AUC: 0.0465
#  F1 Score: 0.2629
#  Precision Score: 0.1669
#  Recall Score: 0.6191
#
#  Evaluate combination: 05/61 (global 4):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 263.50 seconds
#  ROC AUC Score (train): 0.7837
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0456
#  F1 Score: 0.2823
#  Precision Score: 0.2007
#  Recall Score: 0.4757
#  New model found! (F1: 0.2823)
#
#  Evaluate combination: 06/61 (global 5):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 263.36 seconds
#  ROC AUC Score (train): 0.7852
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0471
#  F1 Score: 0.2583
#  Precision Score: 0.1622
#  Recall Score: 0.6340
#
#  Evaluate combination: 07/61 (global 6):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 309.57 seconds
#  ROC AUC Score (train): 0.7861
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0481
#  F1 Score: 0.2617
#  Precision Score: 0.1662
#  Recall Score: 0.6162
#
#  Evaluate combination: 08/61 (global 7):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 308.86 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0468
#  F1 Score: 0.2835
#  Precision Score: 0.2021
#  Recall Score: 0.4745
#  New model found! (F1: 0.2835)
#
#  Evaluate combination: 09/61 (global 8):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 309.30 seconds
#  ROC AUC Score (train): 0.7858
#  ROC AUC Score (Test): 0.7380
#  Difference AUC: 0.0478
#  F1 Score: 0.2602
#  Precision Score: 0.1636
#  Recall Score: 0.6365
#
#  Evaluate combination: 010/61 (global 9):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 222.89 seconds
#  ROC AUC Score (train): 0.7839
#  ROC AUC Score (Test): 0.7389
#  Difference AUC: 0.0450
#  F1 Score: 0.2620
#  Precision Score: 0.1662
#  Recall Score: 0.6194
#
#  Evaluate combination: 011/61 (global 10):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 233.20 seconds
#  ROC AUC Score (train): 0.7828
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0445
#  F1 Score: 0.2807
#  Precision Score: 0.1991
#  Recall Score: 0.4757
#
#  Evaluate combination: 012/61 (global 11):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 231.89 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0459
#  F1 Score: 0.2588
#  Precision Score: 0.1623
#  Recall Score: 0.6388
#
#  Evaluate combination: 013/61 (global 12):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 267.12 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7388
#  Difference AUC: 0.0462
#  F1 Score: 0.2626
#  Precision Score: 0.1667
#  Recall Score: 0.6188
#
#  Evaluate combination: 014/61 (global 13):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 269.07 seconds
#  ROC AUC Score (train): 0.7838
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0453
#  F1 Score: 0.2840
#  Precision Score: 0.2022
#  Recall Score: 0.4767
#  New model found! (F1: 0.2840)
#
#  Evaluate combination: 015/61 (global 14):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 266.62 seconds
#  ROC AUC Score (train): 0.7852
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0470
#  F1 Score: 0.2595
#  Precision Score: 0.1630
#  Recall Score: 0.6362
#
#  Evaluate combination: 016/61 (global 15):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 312.04 seconds
#  ROC AUC Score (train): 0.7861
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0479
#  F1 Score: 0.2630
#  Precision Score: 0.1671
#  Recall Score: 0.6181
#
#  Evaluate combination: 017/61 (global 16):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 308.91 seconds
#  ROC AUC Score (train): 0.7848
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0464
#  F1 Score: 0.2836
#  Precision Score: 0.2018
#  Recall Score: 0.4770
#
#  Evaluate combination: 018/61 (global 17):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 2
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 309.84 seconds
#  ROC AUC Score (train): 0.7859
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0475
#  F1 Score: 0.2602
#  Precision Score: 0.1636
#  Recall Score: 0.6343
#
#  Evaluate combination: 019/61 (global 18):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 223.33 seconds
#  ROC AUC Score (train): 0.7837
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0455
#  F1 Score: 0.2616
#  Precision Score: 0.1660
#  Recall Score: 0.6178
#
#  Evaluate combination: 020/61 (global 19):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 222.87 seconds
#  ROC AUC Score (train): 0.7829
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0445
#  F1 Score: 0.2810
#  Precision Score: 0.1998
#  Recall Score: 0.4732
#
#  Evaluate combination: 021/61 (global 20):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 224.48 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0458
#  F1 Score: 0.2589
#  Precision Score: 0.1625
#  Recall Score: 0.6362
#
#  Evaluate combination: 022/61 (global 21):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 263.01 seconds
#  ROC AUC Score (train): 0.7849
#  ROC AUC Score (Test): 0.7387
#  Difference AUC: 0.0463
#  F1 Score: 0.2629
#  Precision Score: 0.1668
#  Recall Score: 0.6210
#
#  Evaluate combination: 023/61 (global 22):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 265.48 seconds
#  ROC AUC Score (train): 0.7837
#  ROC AUC Score (Test): 0.7385
#  Difference AUC: 0.0453
#  F1 Score: 0.2814
#  Precision Score: 0.2003
#  Recall Score: 0.4729
#
#  Evaluate combination: 024/61 (global 23):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 275.67 seconds
#  ROC AUC Score (train): 0.7855
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0472
#  F1 Score: 0.2590
#  Precision Score: 0.1626
#  Recall Score: 0.6359
#
#  Evaluate combination: 025/61 (global 24):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 307.53 seconds
#  ROC AUC Score (train): 0.7861
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0480
#  F1 Score: 0.2622
#  Precision Score: 0.1665
#  Recall Score: 0.6169
#
#  Evaluate combination: 026/61 (global 25):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 312.07 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0467
#  F1 Score: 0.2831
#  Precision Score: 0.2017
#  Recall Score: 0.4751
#
#  Evaluate combination: 027/61 (global 26):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 310.48 seconds
#  ROC AUC Score (train): 0.7857
#  ROC AUC Score (Test): 0.7379
#  Difference AUC: 0.0478
#  F1 Score: 0.2600
#  Precision Score: 0.1634
#  Recall Score: 0.6362
#
#  Evaluate combination: 028/61 (global 27):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 220.52 seconds
#  ROC AUC Score (train): 0.7839
#  ROC AUC Score (Test): 0.7389
#  Difference AUC: 0.0450
#  F1 Score: 0.2620
#  Precision Score: 0.1662
#  Recall Score: 0.6194
#
#  Evaluate combination: 029/61 (global 28):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 219.84 seconds
#  ROC AUC Score (train): 0.7828
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0445
#  F1 Score: 0.2807
#  Precision Score: 0.1991
#  Recall Score: 0.4757
#
#  Evaluate combination: 030/61 (global 29):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 221.86 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0459
#  F1 Score: 0.2588
#  Precision Score: 0.1623
#  Recall Score: 0.6388
#
#  Evaluate combination: 031/61 (global 30):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 265.40 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7388
#  Difference AUC: 0.0462
#  F1 Score: 0.2626
#  Precision Score: 0.1667
#  Recall Score: 0.6188
#
#  Evaluate combination: 032/61 (global 31):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 261.25 seconds
#  ROC AUC Score (train): 0.7838
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0453
#  F1 Score: 0.2840
#  Precision Score: 0.2022
#  Recall Score: 0.4767
#
#  Evaluate combination: 033/61 (global 32):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 262.33 seconds
#  ROC AUC Score (train): 0.7852
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0470
#  F1 Score: 0.2595
#  Precision Score: 0.1630
#  Recall Score: 0.6362
#
#  Evaluate combination: 034/61 (global 33):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 307.26 seconds
#  ROC AUC Score (train): 0.7861
#  ROC AUC Score (Test): 0.7382
#  Difference AUC: 0.0479
#  F1 Score: 0.2630
#  Precision Score: 0.1671
#  Recall Score: 0.6181
#
#  Evaluate combination: 035/61 (global 34):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 306.60 seconds
#  ROC AUC Score (train): 0.7848
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0464
#  F1 Score: 0.2836
#  Precision Score: 0.2018
#  Recall Score: 0.4770
#
#  Evaluate combination: 036/61 (global 35):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 3
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 306.24 seconds
#  ROC AUC Score (train): 0.7859
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0475
#  F1 Score: 0.2602
#  Precision Score: 0.1636
#  Recall Score: 0.6343
#
#  Evaluate combination: 037/61 (global 36):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 221.54 seconds
#  ROC AUC Score (train): 0.7839
#  ROC AUC Score (Test): 0.7391
#  Difference AUC: 0.0448
#  F1 Score: 0.2623
#  Precision Score: 0.1663
#  Recall Score: 0.6207
#
#  Evaluate combination: 038/61 (global 37):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 221.08 seconds
#  ROC AUC Score (train): 0.7826
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0443
#  F1 Score: 0.2808
#  Precision Score: 0.1995
#  Recall Score: 0.4742
#
#  Evaluate combination: 039/61 (global 38):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 221.33 seconds
#  ROC AUC Score (train): 0.7839
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0455
#  F1 Score: 0.2589
#  Precision Score: 0.1624
#  Recall Score: 0.6384
#
#  Evaluate combination: 040/61 (global 39):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 264.34 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0466
#  F1 Score: 0.2624
#  Precision Score: 0.1664
#  Recall Score: 0.6197
#
#  Evaluate combination: 041/61 (global 40):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 261.90 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7386
#  Difference AUC: 0.0454
#  F1 Score: 0.2818
#  Precision Score: 0.2008
#  Recall Score: 0.4726
#
#  Evaluate combination: 042/61 (global 41):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 261.31 seconds
#  ROC AUC Score (train): 0.7855
#  ROC AUC Score (Test): 0.7378
#  Difference AUC: 0.0477
#  F1 Score: 0.2588
#  Precision Score: 0.1626
#  Recall Score: 0.6340
#
#  Evaluate combination: 043/61 (global 42):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 305.68 seconds
#  ROC AUC Score (train): 0.7862
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0478
#  F1 Score: 0.2631
#  Precision Score: 0.1670
#  Recall Score: 0.6194
#
#  Evaluate combination: 044/61 (global 43):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 306.30 seconds
#  ROC AUC Score (train): 0.7848
#  ROC AUC Score (Test): 0.7380
#  Difference AUC: 0.0468
#  F1 Score: 0.2819
#  Precision Score: 0.2007
#  Recall Score: 0.4732
#
#  Evaluate combination: 045/61 (global 44):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 305.41 seconds
#  ROC AUC Score (train): 0.7858
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0478
#  F1 Score: 0.2596
#  Precision Score: 0.1630
#  Recall Score: 0.6375
#
#  Evaluate combination: 046/61 (global 45):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 221.95 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7391
#  Difference AUC: 0.0449
#  F1 Score: 0.2623
#  Precision Score: 0.1662
#  Recall Score: 0.6210
#
#  Evaluate combination: 047/61 (global 46):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 221.63 seconds
#  ROC AUC Score (train): 0.7827
#  ROC AUC Score (Test): 0.7383
#  Difference AUC: 0.0445
#  F1 Score: 0.2824
#  Precision Score: 0.2005
#  Recall Score: 0.4776
#
#  Evaluate combination: 048/61 (global 47):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 221.23 seconds
#  ROC AUC Score (train): 0.7840
#  ROC AUC Score (Test): 0.7384
#  Difference AUC: 0.0456
#  F1 Score: 0.2590
#  Precision Score: 0.1624
#  Recall Score: 0.6391
#
#  Evaluate combination: 049/61 (global 48):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 261.06 seconds
#  ROC AUC Score (train): 0.7849
#  ROC AUC Score (Test): 0.7381
#  Difference AUC: 0.0467
#  F1 Score: 0.2621
#  Precision Score: 0.1663
#  Recall Score: 0.6181
#
#  Evaluate combination: 050/61 (global 49):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 261.93 seconds
#  ROC AUC Score (train): 0.7839
#  ROC AUC Score (Test): 0.7387
#  Difference AUC: 0.0452
#  F1 Score: 0.2817
#  Precision Score: 0.2006
#  Recall Score: 0.4729
#
#  Evaluate combination: 051/61 (global 50):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 262.34 seconds
#  ROC AUC Score (train): 0.7856
#  ROC AUC Score (Test): 0.7380
#  Difference AUC: 0.0475
#  F1 Score: 0.2586
#  Precision Score: 0.1625
#  Recall Score: 0.6334
#
#  Evaluate combination: 052/61 (global 51):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 304.93 seconds
#  ROC AUC Score (train): 0.7860
#  ROC AUC Score (Test): 0.7385
#  Difference AUC: 0.0475
#  F1 Score: 0.2630
#  Precision Score: 0.1670
#  Recall Score: 0.6191
#
#  Evaluate combination: 053/61 (global 52):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 8}
#  Training time: 313.39 seconds
#  ROC AUC Score (train): 0.7850
#  ROC AUC Score (Test): 0.7379
#  Difference AUC: 0.0471
#  F1 Score: 0.2820
#  Precision Score: 0.2008
#  Recall Score: 0.4738
#
#  Evaluate combination: 054/61 (global 53):
#   n_estimators: 150
#   max_depth: 8
#   min_samples_split: 5
#   min_samples_leaf: 2
#   max_features: 0.7
#   class_weight: {0: 1, 1: 12}
#  Training time: 308.08 seconds
#  ROC AUC Score (train): 0.7857
#  ROC AUC Score (Test): 0.7380
#  Difference AUC: 0.0477
#  F1 Score: 0.2605
#  Precision Score: 0.1637
#  Recall Score: 0.6378
#
#  Evaluate combination: 055/61 (global 54):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: balanced
#  Training time: 275.88 seconds
#  ROC AUC Score (train): 0.8365
#  ROC AUC Score (Test): 0.7403
#  Difference AUC: 0.0962
#  F1 Score: 0.2754
#  Precision Score: 0.1815
#  Recall Score: 0.5709
#
#  Evaluate combination: 056/61 (global 55):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 8}
#  Training time: 274.31 seconds
#  ROC AUC Score (train): 0.8377
#  ROC AUC Score (Test): 0.7410
#  Difference AUC: 0.0967
#  F1 Score: 0.2843
#  Precision Score: 0.2132
#  Recall Score: 0.4266
#  New model found! (F1: 0.2843)
#
#  Evaluate combination: 057/61 (global 56):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.5
#   class_weight: {0: 1, 1: 12}
#  Training time: 275.28 seconds
#  ROC AUC Score (train): 0.8368
#  ROC AUC Score (Test): 0.7408
#  Difference AUC: 0.0960
#  F1 Score: 0.2729
#  Precision Score: 0.1777
#  Recall Score: 0.5886
#
#  Evaluate combination: 058/61 (global 57):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: balanced
#  Training time: 326.35 seconds
#  ROC AUC Score (train): 0.8387
#  ROC AUC Score (Test): 0.7408
#  Difference AUC: 0.0980
#  F1 Score: 0.2759
#  Precision Score: 0.1820
#  Recall Score: 0.5703
#
#  Evaluate combination: 059/61 (global 58):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#  Training time: 327.64 seconds
#  ROC AUC Score (train): 0.8403
#  ROC AUC Score (Test): 0.7408
#  Difference AUC: 0.0994
#  F1 Score: 0.2844
#  Precision Score: 0.2136
#  Recall Score: 0.4253
#  New model found! (F1: 0.2844)
#
#  Evaluate combination: 060/61 (global 59):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 12}
#  Training time: 326.07 seconds
#  ROC AUC Score (train): 0.8380
#  ROC AUC Score (Test): 0.7407
#  Difference AUC: 0.0974
#  F1 Score: 0.2726
#  Precision Score: 0.1775
#  Recall Score: 0.5864
#
#  Evaluate combination: 061/61 (global 60):
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.7
#   class_weight: balanced
#  Training time: 380.18 seconds
#  ROC AUC Score (train): 0.8402
#  ROC AUC Score (Test): 0.7407
#  Difference AUC: 0.0995
#  F1 Score: 0.2789
#  Precision Score: 0.1848
#  Recall Score: 0.5683
#
# ======================================================================
# INSTANCE RESULTS 1 (275.3 MIN)
# ======================================================================
#   BEST TRAIN AUC: 0.8403
#   BEST VAL AUC: 0.7408
#   BEST DIFF AUC: 0.0994
#   BEST F1: 0.2844
#   BEST Precision: 0.2136
#   BEST Recall: 0.4253
#
# BEST PARAMS:
#   n_estimators: 150
#   max_depth: 10
#   min_samples_split: 2
#   min_samples_leaf: 1
#   max_features: 0.6
#   class_weight: {0: 1, 1: 8}
#
# ✅ PROCESS TO INSTANCE: 1 FINISHED

# %% [markdown]
# ## 4. Predict unlabeled data
#
# Now it's time to finally use the `test_data` samples. Because we don't have the labels we can't see how the model performs on this dataset (╯°□°)╯︵ ┻━┻
#
# But... don't worry, we will internally evaluate your model and give feedback on the results!
#
# In the cells below:
# - Take your best model
# - Take `test_data` (i.e. the dataset after doing the preprocessing and feature engineering part)
# - Run the data through your model and save the predictions on the `TARGET` column in the `app_test` DataFrame (yeah that we've loaded at the very beginning of this notebook).
#     - `TARGET` column values must be the probabilities for class 1. So remember to use the `predict_proba()` function from your model as we did in the previous sections.
# - Save the modified version of the DataFrame with the same name it has before (`dataset/application_test_aai.csv`) and don't forget to submit it alongside the rest of this sprint project code
# - And finally, don't get confused, you shouldn't submit `dataset/application_train_aai.csv`. So please don't upload your solution with this heavy dataset inside.
#
# Let's say your best model is called `best_credit_model_ever`, then your code should be exactly this:
#
# ```python
#     test_preds = best_credit_model_ever.predict_proba(test_data)[:, 1]
#     app_test["TARGET"] = test_preds
#     app_test.to_csv(config.DATASET_TEST, index=False)
# ```

# %%
raise ValueError("Check the output of the grid search is the best model")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 raise ValueError("Test dataset type is incorrect, please review your code")
#
# ValueError: Test dataset type is incorrect, please review your code

# %%
# %%time

# 1. Definir el mejor modelo (ajustar al que encontraste como óptimo)
best_model = RandomForestClassifier(
    n_estimators=150,
    max_depth=8,
    min_samples_split=3,
    min_samples_leaf=1,
    max_features=0.5,
    class_weight={0: 1, 1: 8},
    random_state=42
)

# 2. Entrenarlo con tus datos de entrenamiento
print("Entrenando el modelo final...")
best_model.fit(train_data, y_train)
# Out:
# Entrenando el modelo final...
# CPU times: user 9min 50s, sys: 7.4 s, total: 9min 58s
# Wall time: 10min 33s
# RandomForestClassifier(class_weight={0: 1, 1: 8}, max_depth=8, max_features=0.5,
#                        min_samples_split=3, n_estimators=150, random_state=42)

# %%
# 3. Calibrar probabilidades para mejorar estimaciones
from sklearn.calibration import CalibratedClassifierCV


calibrated_model = CalibratedClassifierCV(
    estimator=best_model,
    method='sigmoid',
    cv=5
)


calibrated_model.fit(train_data, y_train)

y_train_pred = calibrated_model.predict(X_train_fold)
y_val_pred = calibrated_model.predict(X_val_fold)


y_train_pred_proba = calibrated_model.predict_proba(X_train_fold)[:, 1]
y_val_pred_proba = calibrated_model.predict_proba(X_val_fold)[:, 1]


roc_auc_train = roc_auc_score(y_train_fold, y_train_pred_proba)
roc_auc_val = roc_auc_score(y_val_fold, y_val_pred_proba)

print(f"ROC AUC Score (Train): {roc_auc_train:.4f}")
print(f"ROC AUC Score (Validation): {roc_auc_val:.4f}")

# FINDING THE BEST THRESHOLD

from sklearn.metrics import f1_score
import numpy as np

val_probs = calibrated_model.predict_proba(val_data)[:, 1]
thresholds = np.arange(0.05, 0.5, 0.01)
best_f1 = 0
best_threshold = 0.5

for threshold in thresholds:
    val_preds = (val_probs >= threshold).astype(int)
    f1 = f1_score(y_val, val_preds)
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = threshold


print(f"Best threshold: {best_threshold:.4f} (F1: {best_f1:.4f})")


print("Generating predictions for test set...")
test_preds = calibrated_model.predict_proba(test_data)[:, 1]


app_test["TARGET"] = test_preds

print(f"Range of predicted probabilities: [{test_preds.min():.4f}, {test_preds.max():.4f}]")
print(f"Average of probabilites: {test_preds.mean():.4f}")

print("Saving predictions..")
app_test.to_csv(config.DATASET_TEST, index=False)
print("✅ Predictions saved successfully!")
# Out:
# ROC AUC Score (Train): 0.7757
# ROC AUC Score (Validation): 0.7750
# Umbral óptimo: 0.1400 (F1 en validación: 0.2939)
# Generando predicciones para datos de prueba...
# Rango de probabilidades predecidas: [0.0173, 0.4608]
# Promedio de probabilidades: 0.0805
# Guardando predicciones...
# ¡Predicciones guardadas exitosamente!

# %% [markdown]
# ## 5. Optional exercises

# %% [markdown]
# ### Optional: Training a LightGBM model

# %% [markdown]
# 5.1. Gradient Boosting Machine is one of the most used machine learning algorithms for tabular data. Lots of competitions have been won using models from libraries like XGBoost or LightGBM. You can try using [LightGBM](https://lightgbm.readthedocs.io/en/latest/) to train a new model an see how it performs compared to the other classifiers you trained.

# %%
### Complete in this cell: train a LightGBM model

# %% [markdown]
# ### Optional: Using Scikit Learn Pipelines

# %% [markdown]
# 5.2. So far you've created special functions or blocks or code to chain operations on data and then train the models. But, reproducibility is important, and you don't want to have to remember the correct steps to follow each time you have new data to train your models. There are a lots of tools out there that can help you with that, here you can use a [Sklearn Pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.Pipeline.html) to process your data.

# %%
### Complete in this cell: use a sklearn Pipeline to automate the cleaning, standardizing and training

# %% [markdown]
# ### Optional: Build your own model and features
#
# 5.3. If you want you can take the original labeled data given and make your own feature selection, data preprocessing, and model tunning. Be creative, the only limit is time and hardware resources. Only be careful and don't modify the previous functions made in the mandatory assignments or, you will break the project tests.
#
# You can even use this newer model to make predictions in the test dataset with hidden labels and submit that.

# %%
### Complete in this cell: Make you own experimentation process
